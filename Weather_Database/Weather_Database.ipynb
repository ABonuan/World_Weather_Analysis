# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
# Import the requests library.
import requests

# Import the OpenWeatherMap API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
                
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kalmunai
# Processing Record 2 of Set 1 | kalemie
# Processing Record 3 of Set 1 | nikolskoye
# Processing Record 4 of Set 1 | faya
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | bima
# Processing Record 7 of Set 1 | kudahuvadhoo
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | fonte boa
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 1 | pevek
# Processing Record 14 of Set 1 | kattivakkam
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | diamantino
# Processing Record 19 of Set 1 | bondo
# Processing Record 20 of Set 1 | bilibino
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | henties bay
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | corinth
# Processing Record 25 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 26 of Set 1 | hedaru
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | butler
# Processing Record 29 of Set 1 | jilmah
# City not found. Skipping...
# Processing Record 30 of Set 1 | sambava
# Processing Record 31 of Set 1 | ostrovnoy
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | jilove
# Processing Record 37 of Set 1 | palmer
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | marsh harbour
# Processing Record 41 of Set 1 | tuatapere
# Processing Record 42 of Set 1 | suratgarh
# Processing Record 43 of Set 1 | pyu
# Processing Record 44 of Set 1 | linchuan
# City not found. Skipping...
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | kaitangata
# Processing Record 48 of Set 1 | middelburg
# Processing Record 49 of Set 1 | cobija
# Processing Record 50 of Set 1 | caraballeda
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | tautira
# Processing Record 4 of Set 2 | ornes
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | bud
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | camopi
# Processing Record 9 of Set 2 | visby
# Processing Record 10 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | upernavik
# Processing Record 13 of Set 2 | kiama
# Processing Record 14 of Set 2 | abu kamal
# Processing Record 15 of Set 2 | hambantota
# Processing Record 16 of Set 2 | villamontes
# Processing Record 17 of Set 2 | kundiawa
# Processing Record 18 of Set 2 | taoudenni
# Processing Record 19 of Set 2 | raudeberg
# Processing Record 20 of Set 2 | ponta do sol
# Processing Record 21 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 2 | lasa
# Processing Record 23 of Set 2 | bandarbeyla
# Processing Record 24 of Set 2 | genc
# Processing Record 25 of Set 2 | norman wells
# Processing Record 26 of Set 2 | ihosy
# Processing Record 27 of Set 2 | otradnoye
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | marawi
# Processing Record 30 of Set 2 | tasiilaq
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | bluff
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | banjar
# Processing Record 35 of Set 2 | strezhevoy
# Processing Record 36 of Set 2 | hami
# Processing Record 37 of Set 2 | andenes
# Processing Record 38 of Set 2 | papara
# Processing Record 39 of Set 2 | tahe
# Processing Record 40 of Set 2 | fairbanks
# Processing Record 41 of Set 2 | hasaki
# Processing Record 42 of Set 2 | darnah
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | grafton
# Processing Record 45 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 2 | mao
# Processing Record 47 of Set 2 | george
# Processing Record 48 of Set 2 | esperance
# Processing Record 49 of Set 2 | iqaluit
# Processing Record 50 of Set 2 | bom jardim
# Processing Record 1 of Set 3 | kargasok
# Processing Record 2 of Set 3 | tuktoyaktuk
# Processing Record 3 of Set 3 | alice springs
# Processing Record 4 of Set 3 | samarai
# Processing Record 5 of Set 3 | fagernes
# Processing Record 6 of Set 3 | nemuro
# Processing Record 7 of Set 3 | nanortalik
# Processing Record 8 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 3 | nushki
# Processing Record 10 of Set 3 | qaanaaq
# Processing Record 11 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 3 | alyangula
# Processing Record 13 of Set 3 | kintinku
# Processing Record 14 of Set 3 | cidreira
# Processing Record 15 of Set 3 | trelew
# Processing Record 16 of Set 3 | ratnagiri
# Processing Record 17 of Set 3 | lagos
# Processing Record 18 of Set 3 | tura
# Processing Record 19 of Set 3 | sabang
# Processing Record 20 of Set 3 | alugan
# Processing Record 21 of Set 3 | butaritari
# Processing Record 22 of Set 3 | barra do garcas
# Processing Record 23 of Set 3 | hofn
# Processing Record 24 of Set 3 | kreminna
# Processing Record 25 of Set 3 | chapais
# Processing Record 26 of Set 3 | bongandanga
# Processing Record 27 of Set 3 | severo-kurilsk
# Processing Record 28 of Set 3 | lebu
# Processing Record 29 of Set 3 | bayir
# Processing Record 30 of Set 3 | westport
# Processing Record 31 of Set 3 | constitucion
# Processing Record 32 of Set 3 | alta floresta
# Processing Record 33 of Set 3 | walla walla
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | saldanha
# Processing Record 36 of Set 3 | lazaro cardenas
# Processing Record 37 of Set 3 | qaqortoq
# Processing Record 38 of Set 3 | lubbenau
# Processing Record 39 of Set 3 | victoria
# Processing Record 40 of Set 3 | podporozhye
# Processing Record 41 of Set 3 | lorengau
# Processing Record 42 of Set 3 | tevaitoa
# Processing Record 43 of Set 3 | muroto
# Processing Record 44 of Set 3 | haines junction
# Processing Record 45 of Set 3 | east london
# Processing Record 46 of Set 3 | baikunthpur
# Processing Record 47 of Set 3 | dogondoutchi
# Processing Record 48 of Set 3 | kidal
# Processing Record 49 of Set 3 | todos santos
# Processing Record 50 of Set 3 | mar del plata
# Processing Record 1 of Set 4 | dzhebariki-khaya
# Processing Record 2 of Set 4 | mumbwa
# Processing Record 3 of Set 4 | road town
# Processing Record 4 of Set 4 | makakilo city
# Processing Record 5 of Set 4 | dikson
# Processing Record 6 of Set 4 | sao joao da barra
# Processing Record 7 of Set 4 | takaka
# Processing Record 8 of Set 4 | zabol
# Processing Record 9 of Set 4 | chokurdakh
# Processing Record 10 of Set 4 | faanui
# Processing Record 11 of Set 4 | tucurui
# Processing Record 12 of Set 4 | sola
# Processing Record 13 of Set 4 | ahipara
# Processing Record 14 of Set 4 | iranshahr
# Processing Record 15 of Set 4 | blackwater
# Processing Record 16 of Set 4 | grindavik
# Processing Record 17 of Set 4 | guerrero negro
# Processing Record 18 of Set 4 | college
# Processing Record 19 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 4 | luderitz
# Processing Record 21 of Set 4 | codrington
# Processing Record 22 of Set 4 | fortuna
# Processing Record 23 of Set 4 | skagen
# Processing Record 24 of Set 4 | isangel
# Processing Record 25 of Set 4 | revda
# Processing Record 26 of Set 4 | carnarvon
# Processing Record 27 of Set 4 | maniitsoq
# Processing Record 28 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 29 of Set 4 | torbay
# Processing Record 30 of Set 4 | shikhazany
# Processing Record 31 of Set 4 | san pedro de ycuamandiyu
# Processing Record 32 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 4 | bagnes
# Processing Record 34 of Set 4 | qazigund
# Processing Record 35 of Set 4 | warkworth
# Processing Record 36 of Set 4 | vardo
# Processing Record 37 of Set 4 | leshukonskoye
# Processing Record 38 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 4 | altamira
# Processing Record 40 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 4 | saint anthony
# Processing Record 42 of Set 4 | avarua
# Processing Record 43 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 44 of Set 4 | naze
# Processing Record 45 of Set 4 | rocha
# Processing Record 46 of Set 4 | airai
# Processing Record 47 of Set 4 | belmonte
# Processing Record 48 of Set 4 | namibe
# Processing Record 49 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 50 of Set 4 | port elizabeth
# Processing Record 1 of Set 5 | honiara
# Processing Record 2 of Set 5 | qui nhon
# Processing Record 3 of Set 5 | bambous virieux
# Processing Record 4 of Set 5 | lagoa
# Processing Record 5 of Set 5 | alofi
# Processing Record 6 of Set 5 | katsuura
# Processing Record 7 of Set 5 | sokoto
# Processing Record 8 of Set 5 | kholtoson
# Processing Record 9 of Set 5 | saskylakh
# Processing Record 10 of Set 5 | porto santo
# Processing Record 11 of Set 5 | biak
# Processing Record 12 of Set 5 | bontang
# Processing Record 13 of Set 5 | menemen
# Processing Record 14 of Set 5 | clyde river
# Processing Record 15 of Set 5 | omboue
# Processing Record 16 of Set 5 | arraial do cabo
# Processing Record 17 of Set 5 | sitka
# Processing Record 18 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 5 | narsaq
# Processing Record 20 of Set 5 | ilulissat
# Processing Record 21 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 22 of Set 5 | pangody
# Processing Record 23 of Set 5 | dawlatabad
# Processing Record 24 of Set 5 | zhigansk
# Processing Record 25 of Set 5 | pekalongan
# Processing Record 26 of Set 5 | carahue
# Processing Record 27 of Set 5 | kodiak
# Processing Record 28 of Set 5 | amapa
# Processing Record 29 of Set 5 | geraldton
# Processing Record 30 of Set 5 | eldama ravine
# Processing Record 31 of Set 5 | gigmoto
# Processing Record 32 of Set 5 | tara
# Processing Record 33 of Set 5 | olafsvik
# Processing Record 34 of Set 5 | shimoda
# Processing Record 35 of Set 5 | casian
# Processing Record 36 of Set 5 | saint-felicien
# Processing Record 37 of Set 5 | hyeres
# Processing Record 38 of Set 5 | xingyi
# Processing Record 39 of Set 5 | bowen
# Processing Record 40 of Set 5 | bengkulu
# Processing Record 41 of Set 5 | udala
# Processing Record 42 of Set 5 | provideniya
# Processing Record 43 of Set 5 | athabasca
# Processing Record 44 of Set 5 | leninsk
# Processing Record 45 of Set 5 | cabo san lucas
# Processing Record 46 of Set 5 | bethel
# Processing Record 47 of Set 5 | hay river
# Processing Record 48 of Set 5 | antofagasta
# Processing Record 49 of Set 5 | manadhoo
# Processing Record 50 of Set 5 | dingle
# Processing Record 1 of Set 6 | steamboat springs
# Processing Record 2 of Set 6 | akhmeta
# Processing Record 3 of Set 6 | vila velha
# Processing Record 4 of Set 6 | castro
# Processing Record 5 of Set 6 | mayumba
# Processing Record 6 of Set 6 | turochak
# Processing Record 7 of Set 6 | gerash
# Processing Record 8 of Set 6 | mantua
# Processing Record 9 of Set 6 | yatou
# Processing Record 10 of Set 6 | abdanan
# Processing Record 11 of Set 6 | puro
# Processing Record 12 of Set 6 | roald
# Processing Record 13 of Set 6 | baykit
# Processing Record 14 of Set 6 | kautokeino
# Processing Record 15 of Set 6 | mount isa
# Processing Record 16 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 17 of Set 6 | tonk
# Processing Record 18 of Set 6 | resistencia
# Processing Record 19 of Set 6 | meulaboh
# Processing Record 20 of Set 6 | monrovia
# Processing Record 21 of Set 6 | nantucket
# Processing Record 22 of Set 6 | mahebourg
# Processing Record 23 of Set 6 | sinnamary
# Processing Record 24 of Set 6 | gambela
# Processing Record 25 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 6 | ussel
# Processing Record 27 of Set 6 | hirado
# Processing Record 28 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 29 of Set 6 | sinop
# Processing Record 30 of Set 6 | lanxi
# Processing Record 31 of Set 6 | ust-tsilma
# Processing Record 32 of Set 6 | sao filipe
# Processing Record 33 of Set 6 | ottappalam
# Processing Record 34 of Set 6 | mount gambier
# Processing Record 35 of Set 6 | nouna
# Processing Record 36 of Set 6 | sampit
# Processing Record 37 of Set 6 | nome
# Processing Record 38 of Set 6 | luxeuil-les-bains
# Processing Record 39 of Set 6 | hongjiang
# Processing Record 40 of Set 6 | teahupoo
# Processing Record 41 of Set 6 | imeni poliny osipenko
# Processing Record 42 of Set 6 | hovd
# Processing Record 43 of Set 6 | cochrane
# Processing Record 44 of Set 6 | comodoro rivadavia
# Processing Record 45 of Set 6 | roma
# Processing Record 46 of Set 6 | kozluk
# Processing Record 47 of Set 6 | krasnoselkup
# Processing Record 48 of Set 6 | lusambo
# Processing Record 49 of Set 6 | san patricio
# Processing Record 50 of Set 6 | mareeba
# Processing Record 1 of Set 7 | praia da vitoria
# Processing Record 2 of Set 7 | port blair
# Processing Record 3 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 7 | aquiraz
# Processing Record 5 of Set 7 | vostok
# Processing Record 6 of Set 7 | padang
# Processing Record 7 of Set 7 | mehamn
# Processing Record 8 of Set 7 | gizo
# Processing Record 9 of Set 7 | carballo
# Processing Record 10 of Set 7 | am timan
# Processing Record 11 of Set 7 | ovsyanka
# Processing Record 12 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 7 | dolores
# Processing Record 14 of Set 7 | vikulovo
# Processing Record 15 of Set 7 | port-gentil
# Processing Record 16 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 7 | chikoy
# City not found. Skipping...
# Processing Record 18 of Set 7 | nizhniy tsasuchey
# Processing Record 19 of Set 7 | vila
# Processing Record 20 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 7 | portland
# Processing Record 22 of Set 7 | nicoya
# Processing Record 23 of Set 7 | paita
# Processing Record 24 of Set 7 | freeport
# Processing Record 25 of Set 7 | banda aceh
# Processing Record 26 of Set 7 | aykhal
# Processing Record 27 of Set 7 | huarmey
# Processing Record 28 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 29 of Set 7 | tiznit
# Processing Record 30 of Set 7 | aasiaat
# Processing Record 31 of Set 7 | lozovik
# Processing Record 32 of Set 7 | bjornevatn
# Processing Record 33 of Set 7 | coihueco
# Processing Record 34 of Set 7 | caravelas
# Processing Record 35 of Set 7 | pemba
# Processing Record 36 of Set 7 | marsaxlokk
# Processing Record 37 of Set 7 | youghal
# Processing Record 38 of Set 7 | coquimbo
# Processing Record 39 of Set 7 | port augusta
# Processing Record 40 of Set 7 | saint-philippe
# Processing Record 41 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 42 of Set 7 | sioux lookout
# Processing Record 43 of Set 7 | san-pedro
# Processing Record 44 of Set 7 | jalu
# Processing Record 45 of Set 7 | neyshabur
# Processing Record 46 of Set 7 | southbridge
# Processing Record 47 of Set 7 | bonthe
# Processing Record 48 of Set 7 | saint george
# Processing Record 49 of Set 7 | millet
# Processing Record 50 of Set 7 | sernur
# Processing Record 1 of Set 8 | hurricane
# Processing Record 2 of Set 8 | gondanglegi
# Processing Record 3 of Set 8 | uberlingen
# Processing Record 4 of Set 8 | waddan
# Processing Record 5 of Set 8 | maralal
# Processing Record 6 of Set 8 | beringovskiy
# Processing Record 7 of Set 8 | ponta delgada
# Processing Record 8 of Set 8 | harnai
# Processing Record 9 of Set 8 | cabedelo
# Processing Record 10 of Set 8 | saint-augustin
# Processing Record 11 of Set 8 | hammerfest
# Processing Record 12 of Set 8 | lavrentiya
# Processing Record 13 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 14 of Set 8 | marsa matruh
# Processing Record 15 of Set 8 | poco verde
# Processing Record 16 of Set 8 | payakumbuh
# Processing Record 17 of Set 8 | changli
# Processing Record 18 of Set 8 | sistranda
# Processing Record 19 of Set 8 | drexel heights
# Processing Record 20 of Set 8 | sinazongwe
# Processing Record 21 of Set 8 | pisco
# Processing Record 22 of Set 8 | banka
# Processing Record 23 of Set 8 | mountain home
# Processing Record 24 of Set 8 | auki
# Processing Record 25 of Set 8 | gamba
# Processing Record 26 of Set 8 | leningradskiy
# Processing Record 27 of Set 8 | eenhana
# Processing Record 28 of Set 8 | broome
# Processing Record 29 of Set 8 | vanimo
# Processing Record 30 of Set 8 | honningsvag
# Processing Record 31 of Set 8 | jeremie
# Processing Record 32 of Set 8 | homer
# Processing Record 33 of Set 8 | komsomolsk-na-amure
# Processing Record 34 of Set 8 | carutapera
# Processing Record 35 of Set 8 | vestmannaeyjar
# Processing Record 36 of Set 8 | pacifica
# Processing Record 37 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 38 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 8 | ancud
# Processing Record 40 of Set 8 | dondo
# Processing Record 41 of Set 8 | santa ana
# Processing Record 42 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 8 | oksfjord
# Processing Record 44 of Set 8 | lamar
# Processing Record 45 of Set 8 | pingliang
# Processing Record 46 of Set 8 | san carlos de bariloche
# Processing Record 47 of Set 8 | shengjin
# Processing Record 48 of Set 8 | tanjong tokong
# City not found. Skipping...
# Processing Record 49 of Set 8 | berlevag
# Processing Record 50 of Set 8 | talnakh
# Processing Record 1 of Set 9 | santa maria
# Processing Record 2 of Set 9 | kavaratti
# Processing Record 3 of Set 9 | asfi
# Processing Record 4 of Set 9 | teodoro sampaio
# Processing Record 5 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 6 of Set 9 | amalapuram
# Processing Record 7 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 9 | nuuk
# Processing Record 9 of Set 9 | shingu
# Processing Record 10 of Set 9 | cayenne
# Processing Record 11 of Set 9 | luzhou
# Processing Record 12 of Set 9 | mocuba
# Processing Record 13 of Set 9 | paamiut
# Processing Record 14 of Set 9 | ascension
# Processing Record 15 of Set 9 | chara
# Processing Record 16 of Set 9 | noyon
# Processing Record 17 of Set 9 | suicheng
# Processing Record 18 of Set 9 | severnoye
# Processing Record 19 of Set 9 | maceio
# Processing Record 20 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 9 | thompson
# Processing Record 22 of Set 9 | dongsheng
# Processing Record 23 of Set 9 | kilindoni
# Processing Record 24 of Set 9 | la uribe
# City not found. Skipping...
# Processing Record 25 of Set 9 | souillac
# Processing Record 26 of Set 9 | kupang
# Processing Record 27 of Set 9 | ola
# Processing Record 28 of Set 9 | tiksi
# Processing Record 29 of Set 9 | aripuana
# Processing Record 30 of Set 9 | stornoway
# Processing Record 31 of Set 9 | puri
# Processing Record 32 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 9 | igrim
# Processing Record 34 of Set 9 | takoradi
# Processing Record 35 of Set 9 | tamandare
# Processing Record 36 of Set 9 | jaramana
# City not found. Skipping...
# Processing Record 37 of Set 9 | churapcha
# Processing Record 38 of Set 9 | maxixe
# Processing Record 39 of Set 9 | gat
# Processing Record 40 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 9 | slave lake
# Processing Record 42 of Set 9 | adrar
# Processing Record 43 of Set 9 | acari
# Processing Record 44 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 45 of Set 9 | petawawa
# Processing Record 46 of Set 9 | laguna
# Processing Record 47 of Set 9 | moji-mirim
# City not found. Skipping...
# Processing Record 48 of Set 9 | aktau
# Processing Record 49 of Set 9 | bayanday
# Processing Record 50 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 1 of Set 10 | buribay
# Processing Record 2 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 3 of Set 10 | shenjiamen
# Processing Record 4 of Set 10 | salalah
# Processing Record 5 of Set 10 | matay
# Processing Record 6 of Set 10 | erhlin
# City not found. Skipping...
# Processing Record 7 of Set 10 | riyadh
# Processing Record 8 of Set 10 | mvuma
# Processing Record 9 of Set 10 | taksimo
# Processing Record 10 of Set 10 | mpika
# Processing Record 11 of Set 10 | dmytrivka
# Processing Record 12 of Set 10 | schiffdorf
# Processing Record 13 of Set 10 | alekseyevka
# Processing Record 14 of Set 10 | tarancon
# Processing Record 15 of Set 10 | zlobin
# Processing Record 16 of Set 10 | iquique
# Processing Record 17 of Set 10 | teya
# Processing Record 18 of Set 10 | olinda
# Processing Record 19 of Set 10 | chuy
# Processing Record 20 of Set 10 | udachnyy
# Processing Record 21 of Set 10 | yaan
# Processing Record 22 of Set 10 | sur
# Processing Record 23 of Set 10 | mahendranagar
# Processing Record 24 of Set 10 | yenagoa
# Processing Record 25 of Set 10 | moissala
# Processing Record 26 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 10 | la palma
# Processing Record 28 of Set 10 | kaabong
# Processing Record 29 of Set 10 | fort nelson
# Processing Record 30 of Set 10 | waingapu
# Processing Record 31 of Set 10 | tobermory
# Processing Record 32 of Set 10 | katherine
# Processing Record 33 of Set 10 | chapleau
# Processing Record 34 of Set 10 | sicamous
# Processing Record 35 of Set 10 | clarence town
# Processing Record 36 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 37 of Set 10 | asau
# Processing Record 38 of Set 10 | dwarka
# Processing Record 39 of Set 10 | kathmandu
# Processing Record 40 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 10 | podor
# Processing Record 42 of Set 10 | rundu
# Processing Record 43 of Set 10 | humaita
# Processing Record 44 of Set 10 | kazuno
# Processing Record 45 of Set 10 | kenai
# Processing Record 46 of Set 10 | general pico
# Processing Record 47 of Set 10 | porbandar
# Processing Record 48 of Set 10 | la romana
# Processing Record 49 of Set 10 | bignona
# Processing Record 50 of Set 10 | savonlinna
# Processing Record 1 of Set 11 | teguldet
# Processing Record 2 of Set 11 | san cristobal
# Processing Record 3 of Set 11 | coffs harbour
# Processing Record 4 of Set 11 | surt
# Processing Record 5 of Set 11 | solnechnyy
# Processing Record 6 of Set 11 | lucea
# Processing Record 7 of Set 11 | masty
# Processing Record 8 of Set 11 | vadgaon
# Processing Record 9 of Set 11 | cockburn town
# Processing Record 10 of Set 11 | malinyi
# Processing Record 11 of Set 11 | oxilithos
# Processing Record 12 of Set 11 | ust-kan
# Processing Record 13 of Set 11 | bambanglipuro
# Processing Record 14 of Set 11 | palasa
# Processing Record 15 of Set 11 | goderich
# Processing Record 16 of Set 11 | kinlochleven
# Processing Record 17 of Set 11 | pacific grove
# Processing Record 18 of Set 11 | makat
# Processing Record 19 of Set 11 | polyanka
# Processing Record 20 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 22 of Set 11 | diu
# Processing Record 23 of Set 11 | novosergiyevka
# Processing Record 24 of Set 11 | akalkot
# Processing Record 25 of Set 11 | turukhansk
# Processing Record 26 of Set 11 | kalety
# Processing Record 27 of Set 11 | sars
# Processing Record 28 of Set 11 | teguise
# Processing Record 29 of Set 11 | sisimiut
# Processing Record 30 of Set 11 | tombouctou
# Processing Record 31 of Set 11 | kuusamo
# Processing Record 32 of Set 11 | corozal
# Processing Record 33 of Set 11 | palana
# Processing Record 34 of Set 11 | arkhangelos
# City not found. Skipping...
# Processing Record 35 of Set 11 | washington
# Processing Record 36 of Set 11 | lamu
# Processing Record 37 of Set 11 | longyearbyen
# Processing Record 38 of Set 11 | kavieng
# Processing Record 39 of Set 11 | rio grande
# Processing Record 40 of Set 11 | vakhrushev
# Processing Record 41 of Set 11 | morwa
# Processing Record 42 of Set 11 | taltal
# Processing Record 43 of Set 11 | luau
# Processing Record 44 of Set 11 | nouadhibou
# Processing Record 45 of Set 11 | dinagat
# Processing Record 46 of Set 11 | yambio
# Processing Record 47 of Set 11 | benghazi
# Processing Record 48 of Set 11 | gobabis
# Processing Record 49 of Set 11 | novovarshavka
# Processing Record 50 of Set 11 | muscat
# Processing Record 1 of Set 12 | stokmarknes
# Processing Record 2 of Set 12 | ostersund
# Processing Record 3 of Set 12 | port hardy
# Processing Record 4 of Set 12 | gboko
# Processing Record 5 of Set 12 | bathsheba
# Processing Record 6 of Set 12 | magdagachi
# Processing Record 7 of Set 12 | lata
# Processing Record 8 of Set 12 | anacortes
# Processing Record 9 of Set 12 | solginskiy
# Processing Record 10 of Set 12 | necochea
# Processing Record 11 of Set 12 | pombia
# Processing Record 12 of Set 12 | doha
# Processing Record 13 of Set 12 | berbera
# Processing Record 14 of Set 12 | victor harbor
# Processing Record 15 of Set 12 | smithers
# Processing Record 16 of Set 12 | uglich
# Processing Record 17 of Set 12 | puerto escondido
# Processing Record 18 of Set 12 | bandiagara
# Processing Record 19 of Set 12 | mitsamiouli
# Processing Record 20 of Set 12 | viking
# Processing Record 21 of Set 12 | cerqueira cesar
# Processing Record 22 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 12 | pedernales
# Processing Record 24 of Set 12 | ucluelet
# Processing Record 25 of Set 12 | morondava
# Processing Record 26 of Set 12 | seminole
# Processing Record 27 of Set 12 | butembo
# Processing Record 28 of Set 12 | pitkyaranta
# Processing Record 29 of Set 12 | sorbhog
# Processing Record 30 of Set 12 | shellbrook
# Processing Record 31 of Set 12 | choya
# Processing Record 32 of Set 12 | ketchikan
# Processing Record 33 of Set 12 | ygatimi
# Processing Record 34 of Set 12 | chicama
# Processing Record 35 of Set 12 | bonnyville
# Processing Record 36 of Set 12 | viransehir
# Processing Record 37 of Set 12 | krasnyy oktyabr
# Processing Record 38 of Set 12 | charlestown
# Processing Record 39 of Set 12 | tyukalinsk
# Processing Record 40 of Set 12 | deputatskiy
# Processing Record 41 of Set 12 | ouesso
# Processing Record 42 of Set 12 | meadow lake
# Processing Record 43 of Set 12 | saint-pierre
# Processing Record 44 of Set 12 | mancio lima
# Processing Record 45 of Set 12 | kruisfontein
# Processing Record 46 of Set 12 | uzunovo
# Processing Record 47 of Set 12 | odweyne
# Processing Record 48 of Set 12 | kijang
# Processing Record 49 of Set 12 | port-cartier
# Processing Record 50 of Set 12 | daru
# Processing Record 1 of Set 13 | sapa
# Processing Record 2 of Set 13 | diffa
# Processing Record 3 of Set 13 | dingli
# Processing Record 4 of Set 13 | mae sai
# Processing Record 5 of Set 13 | marzuq
# Processing Record 6 of Set 13 | cananea
# Processing Record 7 of Set 13 | mashhad
# Processing Record 8 of Set 13 | oranjemund
# Processing Record 9 of Set 13 | harper
# Processing Record 10 of Set 13 | belaya gora
# Processing Record 11 of Set 13 | ulladulla
# Processing Record 12 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 13 of Set 13 | morant bay
# Processing Record 14 of Set 13 | san vicente
# Processing Record 15 of Set 13 | neka
# Processing Record 16 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 17 of Set 13 | guanare
# Processing Record 18 of Set 13 | kununurra
# Processing Record 19 of Set 13 | fernley
# Processing Record 20 of Set 13 | baghdad
# Processing Record 21 of Set 13 | tulagi
# Processing Record 22 of Set 13 | natchitoches
# Processing Record 23 of Set 13 | half moon bay
# Processing Record 24 of Set 13 | neiafu
# Processing Record 25 of Set 13 | sayan
# Processing Record 26 of Set 13 | shache
# Processing Record 27 of Set 13 | effingham
# Processing Record 28 of Set 13 | manyana
# Processing Record 29 of Set 13 | kaniama
# Processing Record 30 of Set 13 | la ronge
# Processing Record 31 of Set 13 | senador pompeu
# Processing Record 32 of Set 13 | tarko-sale
# Processing Record 33 of Set 13 | lebowakgomo
# Processing Record 34 of Set 13 | jiuquan
# Processing Record 35 of Set 13 | nyaunglebin
# Processing Record 36 of Set 13 | klyuchi
# Processing Record 37 of Set 13 | mollendo
# Processing Record 38 of Set 13 | seybaplaya
# Processing Record 39 of Set 13 | samarinda
# Processing Record 40 of Set 13 | changji
# Processing Record 41 of Set 13 | chimbote
# Processing Record 42 of Set 13 | atka
# City not found. Skipping...
# Processing Record 43 of Set 13 | kindu
# Processing Record 44 of Set 13 | birin
# Processing Record 45 of Set 13 | husavik
# Processing Record 46 of Set 13 | deshna
# City not found. Skipping...
# Processing Record 47 of Set 13 | vila franca do campo
# Processing Record 48 of Set 13 | kishanganj
# Processing Record 49 of Set 13 | whyalla
# Processing Record 50 of Set 13 | glendive
# Processing Record 1 of Set 14 | ust-ishim
# Processing Record 2 of Set 14 | menongue
# Processing Record 3 of Set 14 | pindiga
# Processing Record 4 of Set 14 | ovalle
# Processing Record 5 of Set 14 | mangaratiba
# Processing Record 6 of Set 14 | saint-louis
# Processing Record 7 of Set 14 | usinsk
# Processing Record 8 of Set 14 | touros
# Processing Record 9 of Set 14 | lompoc
# Processing Record 10 of Set 14 | ardakan
# Processing Record 11 of Set 14 | rio gallegos
# Processing Record 12 of Set 14 | whitianga
# Processing Record 13 of Set 14 | magnor
# Processing Record 14 of Set 14 | kargil
# Processing Record 15 of Set 14 | umm lajj
# Processing Record 16 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 14 | chengmai
# City not found. Skipping...
# Processing Record 18 of Set 14 | fushun
# Processing Record 19 of Set 14 | shahr-e babak
# Processing Record 20 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 21 of Set 14 | igarapava
# Processing Record 22 of Set 14 | byumba
# Processing Record 23 of Set 14 | quatre cocos
# Processing Record 24 of Set 14 | sept-iles
# Processing Record 25 of Set 14 | camacha
# Processing Record 26 of Set 14 | komsomolskiy
# Processing Record 27 of Set 14 | vrangel
# Processing Record 28 of Set 14 | arman
# Processing Record 29 of Set 14 | luxor
# Processing Record 30 of Set 14 | hamilton
# Processing Record 31 of Set 14 | zeya
# Processing Record 32 of Set 14 | sao jose da coroa grande
# Processing Record 33 of Set 14 | manjeshwar
# Processing Record 34 of Set 14 | phan thiet
# Processing Record 35 of Set 14 | zirandaro
# Processing Record 36 of Set 14 | cankuzo
# Processing Record 37 of Set 14 | dali
# Processing Record 38 of Set 14 | novo aripuana
# Processing Record 39 of Set 14 | kimbe
# Processing Record 40 of Set 14 | santa isabel do rio negro
# Processing Record 41 of Set 14 | arzamas
# Processing Record 42 of Set 14 | ati
# Processing Record 43 of Set 14 | ahuimanu
# Processing Record 44 of Set 14 | baoning
# Processing Record 45 of Set 14 | quelimane
# Processing Record 46 of Set 14 | saratoga springs
# Processing Record 47 of Set 14 | mattawa
# Processing Record 48 of Set 14 | farah
# Processing Record 49 of Set 14 | karratha
# Processing Record 50 of Set 14 | jablunka
# Processing Record 1 of Set 15 | bokoro
# Processing Record 2 of Set 15 | emba
# Processing Record 3 of Set 15 | emerald
# Processing Record 4 of Set 15 | nemyriv
# Processing Record 5 of Set 15 | kempele
# Processing Record 6 of Set 15 | tyup
# Processing Record 7 of Set 15 | araouane
# Processing Record 8 of Set 15 | yining
# Processing Record 9 of Set 15 | pangnirtung
# Processing Record 10 of Set 15 | kahului
# Processing Record 11 of Set 15 | lokoja
# Processing Record 12 of Set 15 | merrill
# Processing Record 13 of Set 15 | muros
# Processing Record 14 of Set 15 | lipetsk
# Processing Record 15 of Set 15 | salinopolis
# Processing Record 16 of Set 15 | yarmouth
# Processing Record 17 of Set 15 | esso
# Processing Record 18 of Set 15 | winneba
# Processing Record 19 of Set 15 | pedara
# Processing Record 20 of Set 15 | hervey bay
# Processing Record 21 of Set 15 | menomonie
# Processing Record 22 of Set 15 | khorixas
# Processing Record 23 of Set 15 | sydney
# Processing Record 24 of Set 15 | malinovoye ozero
# Processing Record 25 of Set 15 | verkhovazhye
# Processing Record 26 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 15 | coruripe
# Processing Record 28 of Set 15 | kismayo
# Processing Record 29 of Set 15 | vao
# Processing Record 30 of Set 15 | dudinka
# Processing Record 31 of Set 15 | ciudad bolivar
# Processing Record 32 of Set 15 | hualmay
# Processing Record 33 of Set 15 | trincomalee
# Processing Record 34 of Set 15 | belaya kholunitsa
# Processing Record 35 of Set 15 | masumbwe
# Processing Record 36 of Set 15 | sao felix do xingu
# Processing Record 37 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 38 of Set 15 | itacarambi
# Processing Record 39 of Set 15 | doka
# Processing Record 40 of Set 15 | makaha
# Processing Record 41 of Set 15 | korla
# Processing Record 42 of Set 15 | tocopilla
# Processing Record 43 of Set 15 | aklavik
# Processing Record 44 of Set 15 | riachao
# Processing Record 45 of Set 15 | payo
# Processing Record 46 of Set 15 | karachi
# Processing Record 47 of Set 15 | popondetta
# Processing Record 48 of Set 15 | dunedin
# Processing Record 49 of Set 15 | baker city
# Processing Record 50 of Set 15 | tome
# Processing Record 1 of Set 16 | nuevo progreso
# Processing Record 2 of Set 16 | ca mau
# Processing Record 3 of Set 16 | vung tau
# Processing Record 4 of Set 16 | mustafakemalpasa
# Processing Record 5 of Set 16 | moranbah
# Processing Record 6 of Set 16 | ybbs
# City not found. Skipping...
# Processing Record 7 of Set 16 | mosquera
# Processing Record 8 of Set 16 | fecamp
# Processing Record 9 of Set 16 | midland
# Processing Record 10 of Set 16 | talaya
# Processing Record 11 of Set 16 | riachao das neves
# Processing Record 12 of Set 16 | celestun
# Processing Record 13 of Set 16 | dzaoudzi
# Processing Record 14 of Set 16 | ballina
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Kalmunai   7.42   81.82     79.57        75         100        0.34
# 1       Kalemie  -5.95   29.19     72.28        67         100        6.35
# 2    Nikolskoye  59.70   30.79     39.20        86          75        2.24
# 3          Faya  18.39   42.45     59.00        22           0        2.28
# 4          Bima  -8.47  118.72     88.56        61          10        2.82
# 5  Kudahuvadhoo   2.67   72.89     82.17        79          47       10.98
# 6          Hilo  19.73 -155.09     86.00        62          75       14.99
# 7     Fonte Boa  -2.50  -66.27     75.31        92          62        1.92
# 8         Kapaa  22.08 -159.32     84.99        74          40       17.22
# 9     Busselton -33.65  115.33     69.01        53          29        5.01
#
#   Country          Current Description
# 0      LK              overcast clouds
# 1      CD              overcast clouds
# 2      RU  light intensity shower rain
# 3      SA                    clear sky
# 4      ID                    clear sky
# 5      MV             scattered clouds
# 6      US                broken clouds
# 7      BR                broken clouds
# 8      US             scattered clouds
# 9      AU             scattered clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kalmunai      LK   7.42   81.82     79.57        75         100
# 1       Kalemie      CD  -5.95   29.19     72.28        67         100
# 2    Nikolskoye      RU  59.70   30.79     39.20        86          75
# 3          Faya      SA  18.39   42.45     59.00        22           0
# 4          Bima      ID  -8.47  118.72     88.56        61          10
# 5  Kudahuvadhoo      MV   2.67   72.89     82.17        79          47
# 6          Hilo      US  19.73 -155.09     86.00        62          75
# 7     Fonte Boa      BR  -2.50  -66.27     75.31        92          62
# 8         Kapaa      US  22.08 -159.32     84.99        74          40
# 9     Busselton      AU -33.65  115.33     69.01        53          29
#
#    Wind Speed          Current Description
# 0        0.34              overcast clouds
# 1        6.35              overcast clouds
# 2        2.24  light intensity shower rain
# 3        2.28                    clear sky
# 4        2.82                    clear sky
# 5       10.98             scattered clouds
# 6       14.99                broken clouds
# 7        1.92                broken clouds
# 8       17.22             scattered clouds
# 9        5.01             scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
